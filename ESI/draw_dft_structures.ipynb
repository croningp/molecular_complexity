# %%
import os
import sys
import pandas as pd
if os.path.realpath('..') not in sys.path: 
    sys.path.append(os.path.realpath('..'))
from utils import plots

# %%
df = pd.read_csv(os.path.join('..','dft_calc','combined.csv'))

# %%
plots.show_molecules(df,range_of_indexes=[0,55],assembly_index='MA')
# Out:
# [10:44:03] WARNING:  Problems/mismatches: Mobile-H( Mobile-H groups: Attachment points, Number)
#
# [10:44:03] WARNING:  Problems/mismatches: Mobile-H( Hydrogens: Locations or number; Mobile-H groups: One instead of multiple, Attachment points, Number)
#
# [10:44:03] WARNING:  Problems/mismatches: Mobile-H( Hydrogens: Locations or number; Mobile-H groups: Attachment points, Number)

# %%
plots.show_molecules(df,range_of_indexes=[55,115],assembly_index='MA')
# Out:
# [10:44:04] WARNING:  Problems/mismatches: Mobile-H( Mobile-H groups: Attachment points, Number)
