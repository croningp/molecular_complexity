# %%
import os
import sys
if os.path.realpath('..') not in sys.path: 
    sys.path.append(os.path.realpath('..'))
from utils import plots
import pandas as pd
from rdkit import Chem

# %%
df_teor = pd.read_pickle(os.path.join('..','data','calculated_data.pkl'))
nmr_exp = pd.read_pickle(os.path.join('..','data','experimental_nmr.pkl'))
ir_exp = pd.read_pickle(os.path.join('..','data','experimental_ir.pkl'))

# %%
plots.show_molecules(df_teor,how_many_structures=55)

# %%
plots.show_molecules(ir_exp,range_of_indexes=[0,50])

# %%
plots.show_molecules(ir_exp,range_of_indexes=[50,100])

# %%
plots.show_molecules(nmr_exp,range_of_indexes=[0,50])

# %%
plots.show_molecules(nmr_exp,range_of_indexes=[50,110])
